# %%
# samples count, mean, standard deviation
n <- floor(rnorm(10000, 500, 100))

# %%
t <- table(n)

# %%
barplot(t)
# Out:
# plot without title

# %%
n <- floor(rnorm(1000, 50, 100))
t <- table(n)
barplot(t)
# Out:
# plot without title
